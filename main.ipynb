# %%
import numpy as np
import pandas as pd
import sklearn as sk

from sklearn import preprocessing

# %%
data = pd.read_csv('data/data.csv', sep=',')

# %%
data2 = data[['stop_time', 'driver_age', 'driver_gender',  'driver_race', 'violation', 'search_conducted', 'is_arrested', 'drugs_related_stop']]

# %%
display(data2)
# Out:
#       stop_time  driver_age driver_gender driver_race violation  \
# 0          1:55        20.0             M       White  Speeding
# 1          8:15        40.0             M       White  Speeding
# 2         23:15        33.0             M       White  Speeding
# 3         17:15        19.0             M       White     Other
# 4         10:00        21.0             F       White  Speeding
# ...         ...         ...           ...         ...       ...
# 52961      1:55         NaN           NaN         NaN       NaN
# 52962      6:43        25.0             M       White  Speeding
# 52963      6:49         NaN           NaN         NaN       NaN
# 52964      7:19        25.0             F       White  Speeding
# 52965       NaN         NaN           NaN         NaN       NaN
#
#       search_conducted is_arrested drugs_related_stop
# 0                False       False              False
# 1                False       False              False
# ...

# %%
data2.isna().any()
# Out:
# stop_time             True
# driver_age            True
# driver_gender         True
# driver_race           True
# violation             True
# search_conducted      True
# is_arrested           True
# drugs_related_stop    True
# dtype: bool

# %%
data2 = data2.dropna()

# %%
display(data2)
# Out:
#       stop_time  driver_age driver_gender driver_race violation  \
# 0          1:55        20.0             M       White  Speeding
# 1          8:15        40.0             M       White  Speeding
# 2         23:15        33.0             M       White  Speeding
# 3         17:15        19.0             M       White     Other
# 4         10:00        21.0             F       White  Speeding
# ...         ...         ...           ...         ...       ...
# 52956     22:22        32.0             M       White  Speeding
# 52958     22:36        44.0             F    Hispanic  Speeding
# 52959     23:25        20.0             F       Black  Speeding
# 52962      6:43        25.0             M       White  Speeding
# 52964      7:19        25.0             F       White  Speeding
#
#       search_conducted is_arrested drugs_related_stop
# 0                False       False              False
# 1                False       False              False
# ...

# %%
data2[['driver_gender',  'driver_race', 'violation', 'search_conducted', 'is_arrested', 'drugs_related_stop']] = data2[['driver_gender',  'driver_race', 'violation', 'search_conducted', 'is_arrested', 'drugs_related_stop']].apply(preprocessing.LabelEncoder().fit_transform()
# Out:
#   Cell In[16], line 1
#     data2[['driver_gender',  'driver_race', 'violation', 'search_conducted', 'is_arrested', 'drugs_related_stop']] = data2[['driver_gender',  'driver_race', 'violation', 'search_conducted', 'is_arrested', 'drugs_related_stop']].apply(preprocessing.LabelEncoder().fit_transform()
#                                                                                                                                                                                                                                          ^
# SyntaxError: '(' was never closed
